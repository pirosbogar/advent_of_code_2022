# %%
import pandas as pd
import numpy as np
import requests
import csv
import string
import requests

# %%
r = requests.get("https://raw.githubusercontent.com/pirosbogar/advent_of_code_2022/main/inputs/06/input.txt")

# %%
r.text
# Out:
# '...\n'

# %%
# Importing data character by character into a df

df = pd.DataFrame(columns=['characters'])

for line in r.text:  
    for ch in line: 
        df = df.append({'characters': ch}, ignore_index=True)
# Out:
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\2437152171.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'characters': ch}, ignore_index=True)
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\2437152171.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'characters': ch}, ignore_index=True)
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\2437152171.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'characters': ch}, ignore_index=True)
# ...

# %%
df.head()
# Out:
#   characters
# 0          p
# 1          l
# 2          h
# 3          l
# 4          s

# %%
len(df)
# Out:
# 4096

# %%
# Creating a df of all the possible markers (combination of 4 characters)
df = pd.DataFrame(columns=['markers'])

for i in range(len(r.text)-1):
    #print(r.text[i:i+4])
    df = df.append({'markers': r.text[i:i+4]}, ignore_index=True)
# Out:
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\3593349011.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'markers': r.text[i:i+4]}, ignore_index=True)
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\3593349011.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'markers': r.text[i:i+4]}, ignore_index=True)
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\3593349011.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'markers': r.text[i:i+4]}, ignore_index=True)
# ...

# %%
df.head()
# Out:
#   markers
# 0    plhl
# 1    lhls
# 2    hlss
# 3    lsss
# 4    sssj

# %%
# Counting each marker's count of unique characters
unique_chars = []

for i in df['markers']:
    unique_chars.append(len(set(i)))

# %%
unique_chars[:5]
# Out:
# [3, 3, 3, 2, 2]

# %%
df2 = pd.DataFrame(list(zip(df['markers'], unique_chars)), columns = ['markers', 'unique_chars'])

# %%
df2.head()
# Out:
#   markers  unique_chars
# 0    plhl             3
# 1    lhls             3
# 2    hlss             3
# 3    lsss             2
# 4    sssj             2

# %% [markdown]
# #### How many characters need to be processed before the first start-of-packet marker (4 different characters appearing before it) is detected?

# %%
# Getting the first row with 4 unique characters. Due to the counting method the answer will be the index number plus 4

print(df2[df2.unique_chars == 4].iloc[0])

print('The answer is: ', df2.index[df2.unique_chars == 4][0] + 4)
# Out:
# markers         czhq
# unique_chars       4
# Name: 1283, dtype: object
# The answer is:  1287

# %% [markdown]
# #### How many characters need to be processed before the first start-of-message marker (14 different characters appearing before it) is detected?

# %%
# Creating a df of all the possible markers (combination of 14 characters)
df3 = pd.DataFrame(columns=['markers'])

for i in range(len(r.text)-1):
    df3 = df3.append({'markers': r.text[i:i+14]}, ignore_index=True)
# Out:
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\3539117513.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append({'markers': r.text[i:i+14]}, ignore_index=True)
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\3539117513.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append({'markers': r.text[i:i+14]}, ignore_index=True)
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_14192\3539117513.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append({'markers': r.text[i:i+14]}, ignore_index=True)
# ...

# %%
# Counting each marker's count of unique characters
unique_chars2 = []

for i in df3['markers']:
    unique_chars2.append(len(set(i)))

# %%
df4 = pd.DataFrame(list(zip(df3['markers'], unique_chars2)), columns = ['markers', 'unique_chars'])

# %%
# Getting the first row with 14 unique characters. Due to the counting method the answer will be the index number plus 14

df4[df4.unique_chars == 14].iloc[0]
# Out:
# markers         rtbwsjzqhgfldn
# unique_chars                14
# Name: 3702, dtype: object

# %%
print(df4.index[df4.unique_chars == 14][0])
print('The answer is: ', df4.index[df4.unique_chars == 14][0] + 14)
# Out:
# 3702
# The answer is:  3716
