# %%
import pandas as pd
import numpy as np
import requests
import csv
import string
import requests
import math

# %%
r = requests.get("https://raw.githubusercontent.com/pirosbogar/advent_of_code_2022/main/inputs/11/input.txt")

# %%
print(r.text)
# Out:
# Monkey 0:
#   Starting items: 75, 63
#   Operation: new = old * 3
#   Test: divisible by 11
#     If true: throw to monkey 7
#     If false: throw to monkey 2
#
# Monkey 1:
#   Starting items: 65, 79, 98, 77, 56, 54, 83, 94
#   Operation: new = old + 3
#   Test: divisible by 2
#     If true: throw to monkey 2
#     If false: throw to monkey 0
#
# Monkey 2:
#   Starting items: 66
#   Operation: new = old + 5
#   Test: divisible by 5
#     If true: throw to monkey 7
#     If false: throw to monkey 5
#
# Monkey 3:
#   Starting items: 51, 89, 90
#   Operation: new = old * 19
#   Test: divisible by 7
#     If true: throw to monkey 6
#     If false: throw to monkey 4
#
# Monkey 4:
#   Starting items: 75, 94, 66, 90, 77, 82, 61
#   Operation: new = old + 1
#   Test: divisible by 17
#     If true: throw to monkey 6
#     If false: throw to monkey 1
#
# Monkey 5:
#   Starting items: 53, 76, 59, 92, 95
#   Operation: new = old + 2
#   Test: divisible by 19
#     If true: throw to monkey 4
# ...

# %%
data = [
    [1,'monkey0', 75],
    [1,'monkey0', 63],
    [1,'monkey1', 65],
    [1,'monkey1', 79],
    [1,'monkey1', 98],
    [1,'monkey1', 77],
    [1,'monkey1', 56],
    [1,'monkey1', 54],
    [1,'monkey1', 83],
    [1,'monkey1', 94],
    [1,'monkey2', 66],
    [1,'monkey3', 51],
    [1,'monkey3', 89],
    [1,'monkey3', 90],
    [1,'monkey4', 75],
    [1,'monkey4', 94],
    [1,'monkey4', 66],
    [1,'monkey4', 90],
    [1,'monkey4', 77],
    [1,'monkey4', 82],
    [1,'monkey4', 61],
    [1,'monkey5', 53],
    [1,'monkey5', 76],
    [1,'monkey5', 59],
    [1,'monkey5', 92],
    [1,'monkey5', 95],
    [1,'monkey6', 81],
    [1,'monkey6', 61],
    [1,'monkey6', 75],
    [1,'monkey6', 89],
    [1,'monkey6', 70],
    [1,'monkey6', 92],
    [1,'monkey7', 81],
    [1,'monkey7', 86],
    [1,'monkey7', 62],
    [1,'monkey7', 87],
]

inventory = pd.DataFrame(data, columns = ['round_cnt', 'monkey', 'worry_level'])

# %%
print(inventory.head())
print(len(inventory))
# Out:
#    round_cnt   monkey  worry_level
# 0          1  monkey0           75
# 1          1  monkey0           63
# 2          1  monkey1           65
# 3          1  monkey1           79
# 4          1  monkey1           98
# 36

# %%
round_counter = 1
inspection_counter = 1

new_inventory = pd.DataFrame(data, columns = ['round_cnt', 'monkey', 'worry_level'])

while round_counter <= 20:
    while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
        for a, b, c in zip(inventory.round_cnt, inventory.monkey, inventory.worry_level):
            if b == 'monkey0':
                x = math.floor((c * 3) / 3)
                if x % 11 == 0:
                    inventory.append([round_counter + 1, 'monkey7', x])
                elif x % 11 != 0:
                    inventory.append([round_counter + 1, 'monkey2', x])

            elif b == 'monkey1':
                x = math.floor((c + 3) / 3)
                if x % 2 == 0:
                    inventory.append([round_counter + 1, 'monkey2', x])
                elif x % 2 != 0:
                    inventory.append([round_counter + 1, 'monkey0', x])

            elif b == 'monkey2':
                x = math.floor((c + 5) / 3)
                if x % 5 == 0:
                    inventory.append([round_counter + 1, 'monkey7', x])
                elif x % 5 != 0:
                    inventory.append([round_counter + 1, 'monkey5', x])

            elif b == 'monkey3':
                x = math.floor((c * 19) / 3)
                if x % 7 == 0:
                    inventory.append([round_counter + 1, 'monkey6', x])
                elif x % 7 != 0:
                    inventory.append([round_counter + 1, 'monkey4', x])

            elif b == 'monkey4':
                x = math.floor((c + 1) / 3)
                if x % 17 == 0:
                    inventory.append([round_counter + 1, 'monkey6', x])
                elif x % 17 != 0:
                    inventory.append([round_counter + 1, 'monkey1', x])

            elif b == 'monkey5':
                x = math.floor((c + 2) / 3)
                if x % 19 == 0:
                    inventory.append([round_counter + 1, 'monkey4', x])
                elif x % 19 != 0:
                    inventory.append([round_counter + 1, 'monkey3', x])

            elif b == 'monkey5':
                x = math.floor((c * c) / 3)
                if x % 3 == 0:
                    inventory.append([round_counter + 1, 'monkey0', x])
                elif x % 3 != 0:
                    inventory.append([round_counter + 1, 'monkey1', x])

            elif b == 'monkey6':
                x = math.floor((c + 8) / 3)
                if x % 13 == 0:
                    inventory.append([round_counter + 1, 'monkey3', x])
                elif x % 13 != 0:
                    inventory.append([round_counter + 1, 'monkey5', x])

            inspection_counter += 1

        round_counter += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 round_counter = 1
#       2 inspection_counter = 1
# ----> 4 new_inventory = pd.DataFrame(data, columns = ['round_cnt', 'monkey', 'worry_level'])
#       6 while round_counter <= 20:
#       7     while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
#
# NameError: name 'pd' is not defined

# %%
round_counter = 1
inspection_counter = 1

while round_counter <= 20:
    while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
        for a, b, c in zip(inventory.round_cnt, inventory.monkey, inventory.worry_level):
            if b == 'monkey0':
                x = math.floor((c * 3) / 3)
                if x % 11 == 0:
                    inventory.append([round_counter + 1, 'monkey7', x])
                    inspection_counter += 1
                elif x % 11 != 0:
                    inventory.append([round_counter + 1, 'monkey2', x])
                    inspection_counter += 1

            elif b == 'monkey1':
                x = math.floor((c + 3) / 3)
                if x % 2 == 0:
                    inventory.append([round_counter + 1, 'monkey2', x])
                    inspection_counter += 1
                elif x % 2 != 0:
                    inventory.append([round_counter + 1, 'monkey0', x])
                    inspection_counter += 1

            elif b == 'monkey2':
                x = math.floor((c + 5) / 3)
                if x % 5 == 0:
                    inventory.append([round_counter + 1, 'monkey7', x])
                    inspection_counter += 1
                elif x % 5 != 0:
                    inventory.append([round_counter + 1, 'monkey5', x])
                    inspection_counter += 1

            elif b == 'monkey3':
                x = math.floor((c * 19) / 3)
                if x % 7 == 0:
                    inventory.append([round_counter + 1, 'monkey6', x])
                    inspection_counter += 1
                elif x % 7 != 0:
                    inventory.append([round_counter + 1, 'monkey4', x])
                    inspection_counter += 1

            elif b == 'monkey4':
                x = math.floor((c + 1) / 3)
                if x % 17 == 0:
                    inventory.append([round_counter + 1, 'monkey6', x])
                    inspection_counter += 1
                elif x % 17 != 0:
                    inventory.append([round_counter + 1, 'monkey1', x])
                    inspection_counter += 1

            elif b == 'monkey5':
                x = math.floor((c + 2) / 3)
                if x % 19 == 0:
                    inventory.append([round_counter + 1, 'monkey4', x])
                    inspection_counter += 1
                elif x % 19 != 0:
                    inventory.append([round_counter + 1, 'monkey3', x])
                    inspection_counter += 1

            elif b == 'monkey5':
                x = math.floor((c * c) / 3)
                if x % 3 == 0:
                    inventory.append([round_counter + 1, 'monkey0', x])
                    inspection_counter += 1
                elif x % 3 != 0:
                    inventory.append([round_counter + 1, 'monkey1', x])
                    inspection_counter += 1

            elif b == 'monkey6':
                x = math.floor((c + 8) / 3)
                if x % 13 == 0:
                    inventory.append([round_counter + 1, 'monkey3', x])
                    inspection_counter += 1
                elif x % 13 != 0:
                    inventory.append([round_counter + 1, 'monkey5', x])
                    inspection_counter += 1

    round_counter += 1
# Out:
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_16068\4232033631.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   inventory.append([round_counter + 1, 'monkey2', x])
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_16068\4232033631.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   inventory.append([round_counter + 1, 'monkey2', x])
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_16068\4232033631.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   inventory.append([round_counter + 1, 'monkey0', x])
# C:\Users\feherdavid\AppData\Local\Temp\ipykernel_16068\4232033631.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
print(inventory)
# Out:
#     round_cnt   monkey  worry_level
# 0           1  monkey0           75
# 1           1  monkey0           63
# 2           1  monkey1           65
# 3           1  monkey1           79
# 4           1  monkey1           98
# 5           1  monkey1           77
# 6           1  monkey1           56
# 7           1  monkey1           54
# 8           1  monkey1           83
# 9           1  monkey1           94
# 10          1  monkey2           66
# 11          1  monkey3           51
# 12          1  monkey3           89
# 13          1  monkey3           90
# 14          1  monkey4           75
# 15          1  monkey4           94
# 16          1  monkey4           66
# 17          1  monkey4           90
# 18          1  monkey4           77
# 19          1  monkey4           82
# 20          1  monkey4           61
# 21          1  monkey5           53
# 22          1  monkey5           76
# 23          1  monkey5           59
# 24          1  monkey5           92
# ...

# %%
from tqdm.notebook import trange, tqdm
from time import sleep

# %%
for i in trange(4): #first loop
    for j in tqdm(range(100)): #Nested loop
        sleep(0.01)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
inspection_counter = 1

while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
    for a, b, c in tqdm(zip(inventory.round_cnt, inventory.monkey, inventory.worry_level)):
        if b == 'monkey0':
            if math.floor((c * 3) / 3) % 11 == 0:
                inventory.append([round_counter + 1, 'monkey7', (math.floor((c * 3) / 3))])
                inspection_counter += 1
            elif math.floor((c * 3) / 3) % 11 != 0:
                inventory.append([round_counter + 1, 'monkey2', (math.floor((c * 3) / 3))])
                inspection_counter += 1

        elif b == 'monkey1': 
            if math.floor((c + 3) / 3) % 2 == 0:
                inventory.append([round_counter + 1, 'monkey2', math.floor((c + 3) / 3)])
                inspection_counter += 1
            elif math.floor((c + 3) / 3) % 2 != 0:
                inventory.append([round_counter + 1, 'monkey0', math.floor((c + 3) / 3)])
                inspection_counter += 1

        elif b == 'monkey2':
            x = math.floor((c + 5) / 3)
            if x % 5 == 0:
                inventory.append([round_counter + 1, 'monkey7', x])
                inspection_counter += 1
            elif x % 5 != 0:
                inventory.append([round_counter + 1, 'monkey5', x])
                inspection_counter += 1

        elif b == 'monkey3':
            x = math.floor((c * 19) / 3)
            if x % 7 == 0:
                inventory.append([round_counter + 1, 'monkey6', x])
                inspection_counter += 1
            elif x % 7 != 0:
                inventory.append([round_counter + 1, 'monkey4', x])
                inspection_counter += 1

        elif b == 'monkey4':
            x = math.floor((c + 1) / 3)
            if x % 17 == 0:
                inventory.append([round_counter + 1, 'monkey6', x])
                inspection_counter += 1
            elif x % 17 != 0:
                inventory.append([round_counter + 1, 'monkey1', x])
                inspection_counter += 1

        elif b == 'monkey5':
            x = math.floor((c + 2) / 3)
            if x % 19 == 0:
                inventory.append([round_counter + 1, 'monkey4', x])
                inspection_counter += 1
            elif x % 19 != 0:
                inventory.append([round_counter + 1, 'monkey3', x])
                inspection_counter += 1

        elif b == 'monkey5':
            x = math.floor((c * c) / 3)
            if x % 3 == 0:
                inventory.append([round_counter + 1, 'monkey0', x])
                inspection_counter += 1
            elif x % 3 != 0:
                inventory.append([round_counter + 1, 'monkey1', x])
                inspection_counter += 1

        elif b == 'monkey6':
            x = math.floor((c + 8) / 3)
            if x % 13 == 0:
                inventory.append([round_counter + 1, 'monkey3', x])
                inspection_counter += 1
            elif x % 13 != 0:
                inventory.append([round_counter + 1, 'monkey5', x])
                inspection_counter += 1

# %%
inspection_counter
# Out:
# 1

# %%
inspection_counter = 1

while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
    for a, b, c in zip(inventory.round_cnt, inventory.monkey, inventory.worry_level):
        if b == 'monkey0':
            x = math.floor((c * 3) / 3)
            if x % 11 == 0:
                inventory.append([round_counter + 1, 'monkey7', x])
            elif x % 11 != 0:
                inventory.append([round_counter + 1, 'monkey2', x])

        elif b == 'monkey1':
            x = math.floor((c + 3) / 3)
            if x % 2 == 0:
                inventory.append([round_counter + 1, 'monkey2', x])
            elif x % 2 != 0:
                inventory.append([round_counter + 1, 'monkey0', x])

        elif b == 'monkey2':
            x = math.floor((c + 5) / 3)
            if x % 5 == 0:
                inventory.append([round_counter + 1, 'monkey7', x])
            elif x % 5 != 0:
                inventory.append([round_counter + 1, 'monkey5', x])

        elif b == 'monkey3':
            x = math.floor((c * 19) / 3)
            if x % 7 == 0:
                inventory.append([round_counter + 1, 'monkey6', x])
            elif x % 7 != 0:
                inventory.append([round_counter + 1, 'monkey4', x])

        elif b == 'monkey4':
            x = math.floor((c + 1) / 3)
            if x % 17 == 0:
                inventory.append([round_counter + 1, 'monkey6', x])
            elif x % 17 != 0:
                inventory.append([round_counter + 1, 'monkey1', x])

        elif b == 'monkey5':
            x = math.floor((c + 2) / 3)
            if x % 19 == 0:
                inventory.append([round_counter + 1, 'monkey4', x])
            elif x % 19 != 0:
                inventory.append([round_counter + 1, 'monkey3', x])

        elif b == 'monkey5':
            x = math.floor((c * c) / 3)
            if x % 3 == 0:
                inventory.append([round_counter + 1, 'monkey0', x])
            elif x % 3 != 0:
                inventory.append([round_counter + 1, 'monkey1', x])

        elif b == 'monkey6':
            x = math.floor((c + 8) / 3)
            if x % 13 == 0:
                inventory.append([round_counter + 1, 'monkey3', x])
            elif x % 13 != 0:
                inventory.append([round_counter + 1, 'monkey5', x])

    inspection_counter += 1

# %%
print(inventory)
# Out:
#        round_cnt   monkey  worry_level
# 0              1  monkey0           75
# 1              1  monkey0           63
# 2              1  monkey1           65
# 3              1  monkey1           79
# 4              1  monkey1           98
# ...          ...      ...          ...
# 14339          2  monkey1            8
# 14340          2  monkey5            8
# 14341          2  monkey5           14
# 14342          2  monkey5           22
# 14343          2  monkey3            8
#
# [14344 rows x 3 columns]

# %%
round_counter = 1
inspection_counter = 1

while round_counter <= 20:
    while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
        for a, b, c in tqdm(zip(inventory.round_cnt, inventory.monkey, inventory.worry_level)):
            if b == 'monkey0':
                x = math.floor((c * 3) / 3)
                if x % 11 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey7', x]
                elif x % 11 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey2', x]

            elif b == 'monkey1':
                x = math.floor((c + 3) / 3)
                if x % 2 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey2', x]
                elif x % 2 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey0', x]

            elif b == 'monkey2':
                x = math.floor((c + 5) / 3)
                if x % 5 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey7', x]
                elif x % 5 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey5', x]

            elif b == 'monkey3':
                x = math.floor((c * 19) / 3)
                if x % 7 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey6', x]
                elif x % 7 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey4', x]

            elif b == 'monkey4':
                x = math.floor((c + 1) / 3)
                if x % 17 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey6', x]
                elif x % 17 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey1', x]

            elif b == 'monkey5':
                x = math.floor((c + 2) / 3)
                if x % 19 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey4', x]
                elif x % 19 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey3', x]

            elif b == 'monkey5':
                x = math.floor((c * c) / 3)
                if x % 3 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey0', x]
                elif x % 3 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey1', x]

            elif b == 'monkey6':
                x = math.floor((c + 8) / 3)
                if x % 13 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey3', x]
                elif x % 13 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey5', x]

        inspection_counter += 1

    round_counter += 1
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [52], in <cell line: 4>()
#      45         inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey4', x]
#      46     elif x % 19 != 0:
# ---> 47         inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey3', x]
#      49 elif b == 'monkey5':
#      50     x = math.floor((c * c) / 3)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# ...

# %%
round_counter = 1
inspection_counter = 1
monkey0_cnt = 0
monkey1_cnt = 0
monkey2_cnt = 0
monkey3_cnt = 0
monkey4_cnt = 0
monkey5_cnt = 0
monkey6_cnt = 0
monkey7_cnt = 0

while round_counter <= 20:
    while inspection_counter <= len(inventory[inventory['round_cnt'] == round_counter]):
        for a, b, c in tqdm(zip(inventory.round_cnt, inventory.monkey, inventory.worry_level)):
            if b == 'monkey0':
                x = math.floor((c * 3) / 3)
                if x % 11 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey7', x]
                elif x % 11 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey2', x]
                inspection_counter += 1
                monkey0_cnt += 1

            elif b == 'monkey1':
                x = math.floor((c + 3) / 3)
                if x % 2 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey2', x]
                elif x % 2 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey0', x]
                inspection_counter += 1
                monkey1_cnt += 1

            elif b == 'monkey2':
                x = math.floor((c + 5) / 3)
                if x % 5 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey7', x]
                elif x % 5 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey5', x]
                inspection_counter += 1
                monkey2_cnt += 1

            elif b == 'monkey3':
                x = math.floor((c * 19) / 3)
                if x % 7 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey6', x]
                elif x % 7 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey4', x]
                inspection_counter += 1
                monkey3_cnt += 1

            elif b == 'monkey4':
                x = math.floor((c + 1) / 3)
                if x % 17 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey6', x]
                elif x % 17 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey1', x]
                inspection_counter += 1
                monkey4_cnt += 1

            elif b == 'monkey5':
                x = math.floor((c + 2) / 3)
                if x % 19 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey4', x]
                elif x % 19 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey3', x]
                inspection_counter += 1
                monkey5_cnt += 1

            elif b == 'monkey5':
                x = math.floor((c * c) / 3)
                if x % 3 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey0', x]
                elif x % 3 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey1', x]
                inspection_counter += 1
                monkey6_cnt += 1

            elif b == 'monkey6':
                x = math.floor((c + 8) / 3)
                if x % 13 == 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey3', x]
                elif x % 13 != 0:
                    inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey5', x]
                inspection_counter += 1
                monkey7_cnt += 1

    inspection_counter = 1
    round_counter += 1
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [90], in <cell line: 12>()
#      25 x = math.floor((c + 3) / 3)
#      26 if x % 2 == 0:
# ---> 27     inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey2', x]
#      28 elif x % 2 != 0:
#      29     inventory.loc[len(inventory.index)] = [round_counter + 1, 'monkey0', x]
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# ...

# %%
inspection_counter
# Out:
# 12876

# %%
round_counter
# Out:
# 9

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(inventory)
# Out:
#        round_cnt   monkey  worry_level
# 0              1  monkey0           75
# 1              1  monkey0           63
# 2              1  monkey1           65
# 3              1  monkey1           79
# 4              1  monkey1           98
# 5              1  monkey1           77
# 6              1  monkey1           56
# 7              1  monkey1           54
# 8              1  monkey1           83
# 9              1  monkey1           94
# 10             1  monkey2           66
# 11             1  monkey3           51
# 12             1  monkey3           89
# 13             1  monkey3           90
# 14             1  monkey4           75
# 15             1  monkey4           94
# 16             1  monkey4           66
# 17             1  monkey4           90
# 18             1  monkey4           77
# 19             1  monkey4           82
# 20             1  monkey4           61
# 21             1  monkey5           53
# 22             1  monkey5           76
# ...

# %%
monkey0_cnt
# Out:
# 8

# %%
monkey4_cnt
# Out:
# 17
